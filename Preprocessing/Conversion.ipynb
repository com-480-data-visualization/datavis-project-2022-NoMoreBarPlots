# %%
import numpy as np
import pandas as pd

DATA_PATH = 'Data_clean/'

# %%
FILE_NAME = 'Additives and Oxygenates'
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 30 TJ/(thousand of tons) --> 8.33e6 kWh/(thousand of tons)
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 8.33e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0 Country or Area  \
# 0              0     Afghanistan
# 1              1     Afghanistan
# 2              2     Afghanistan
# 3              3     Afghanistan
# 4              4     Afghanistan
# ...          ...             ...
# 4128        4128   United States
# 4129        4129   United States
# 4130        4130   United States
# 4131        4131   United States
# 4132        4132   United States
#
#                                 Commodity - Transaction  \
# 0                    Additives and Oxygenates - Imports
# 1                    Additives and Oxygenates - Imports
# 2             Additives and Oxygenates - Transformation
# 3             Additives and Oxygenates - Transformation
# 4     Additives and Oxygenates - Transformation in o...
# ...                                                 ...
# 4128     Additives and Oxygenates - Total energy supply
# 4129     Additives and Oxygenates - Total energy supply
# ...

# %%
FILE_NAME = 'Animal waste'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 277778*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0 Country or Area           Commodity - Transaction  \
# 0              0         Armenia         Animal waste - Production
# 1              1         Armenia         Animal waste - Production
# 2              2         Armenia         Animal waste - Production
# 3              3         Armenia         Animal waste - Production
# 4              4         Armenia         Animal waste - Production
# ...          ...             ...                               ...
# 2876        2876   United States  Animal waste - Final consumption
# 2877        2877   United States  Animal waste - Final consumption
# 2878        2878   United States  Animal waste - Final consumption
# 2879        2879   United States  Animal waste - Final consumption
# 2880        2880   United States  Animal waste - Final consumption
#
#          Commodity        Transaction  Year        Unit       Quantity  \
# 0     Animal waste         Production  2019  Terajoules     871.315000
# ...

# %%
FILE_NAME = 'Anthracite'
#http://revelle.net/lakeside/energy_conversions.html#:~:text=They%20report%20that%20one%20ton,or%207%2C326%20KWh%20of%20electricity. --> 7326e3 kWh/(thousands of tons)
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 7.326e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0 Country or Area           Commodity - Transaction  \
# 0              0         Albania              Anthracite - imports
# 1              1         Albania              Anthracite - imports
# 2              2         Albania              Anthracite - imports
# 3              3         Albania              Anthracite - imports
# 4              4         Albania              Anthracite - imports
# ...          ...             ...                               ...
# 8341        8341        Zimbabwe  Anthracite - Total energy supply
# 8342        8342        Zimbabwe  Anthracite - Total energy supply
# 8343        8343        Zimbabwe  Anthracite - Total energy supply
# 8344        8344        Zimbabwe  Anthracite - Total energy supply
# 8345        8345        Zimbabwe  Anthracite - Total energy supply
#
#        Commodity          Transaction  Year                    Unit  Quantity  \
# 0     Anthracite              imports  2020  Metric tons,  thousand    137.43
# ...

# %%
FILE_NAME = 'Aviation gasoline'
#https://hypertextbook.com/facts/2003/EvelynGofman.shtml --> 45 MJ/kg --> 12.5e6 kWh/(thousand of tons)
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 12.5e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area  \
# 0               0     Afghanistan
# 1               1     Afghanistan
# 2               2     Afghanistan
# 3               3     Afghanistan
# 4               4     Afghanistan
# ...           ...             ...
# 23001       23001        Zimbabwe
# 23002       23002        Zimbabwe
# 23003       23003        Zimbabwe
# 23004       23004        Zimbabwe
# 23005       23005        Zimbabwe
#
#                                  Commodity - Transaction          Commodity  \
# 0      Aviation gasoline - International aviation bun...  Aviation gasoline
# 1      Aviation gasoline - International aviation bun...  Aviation gasoline
# 2      Aviation gasoline - International aviation bun...  Aviation gasoline
# 3                      Aviation gasoline - Stock changes  Aviation gasoline
# 4                      Aviation gasoline - Stock changes  Aviation gasoline
# ...                                                  ...                ...
# ...

# %%
FILE_NAME = 'Bagasse'
#https://www.gastronomiac.com/ustensiles_et_vocabu/bagasse/ --> 7900 kJ/kg --> 2.19e6 kWh/(thousand of tons)
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 2.19e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area      Commodity - Transaction Commodity  \
# 0               0          Angola         Bagasse - Production   Bagasse
# 1               1          Angola         Bagasse - Production   Bagasse
# 2               2          Angola         Bagasse - Production   Bagasse
# 3               3          Angola         Bagasse - Production   Bagasse
# 4               4          Angola         Bagasse - Production   Bagasse
# ...           ...             ...                          ...       ...
# 18429       18429        Zimbabwe  Bagasse - Final consumption   Bagasse
# 18430       18430        Zimbabwe  Bagasse - Final consumption   Bagasse
# 18431       18431        Zimbabwe  Bagasse - Final consumption   Bagasse
# 18432       18432        Zimbabwe  Bagasse - Final consumption   Bagasse
# 18433       18433        Zimbabwe  Bagasse - Final consumption   Bagasse
#
#              Transaction  Year                    Unit  Quantity  \
# ...

# %%
FILE_NAME = 'Bio jet kerosene'
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 40 TJ/(thousand of tons) --> 11.1e6 kWh/(thousand of tons)
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 11.1e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#     Unnamed: 0 Country or Area                 Commodity - Transaction  \
# 0            0         Finland           Bio jet kerosene - Production
# 1            1         Finland           Bio jet kerosene - Production
# 2            2         Finland           Bio jet kerosene - Production
# 3            3         Finland           Bio jet kerosene - Production
# 4            4         Finland           Bio jet kerosene - Production
# 5            5         Finland              Bio jet kerosene - Exports
# 6            6         Finland              Bio jet kerosene - Exports
# 7            7         Finland              Bio jet kerosene - Exports
# 8            8         Finland              Bio jet kerosene - Exports
# 9            9         Finland              Bio jet kerosene - Exports
# 10          10         Finland        Bio jet kerosene - Stock changes
# 11          11         Finland        Bio jet kerosene - Stock changes
# ...

# %%
FILE_NAME = 'Biodiesel'
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 36.8 TJ/(thousand of tons) --> 10e6 kWh/(thousand of tons)
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 10e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0 Country or Area        Commodity - Transaction  Commodity  \
# 0              0         Albania            Biodiesel - Imports  Biodiesel
# 1              1         Albania            Biodiesel - Imports  Biodiesel
# 2              2         Albania            Biodiesel - Imports  Biodiesel
# 3              3         Albania            Biodiesel - Imports  Biodiesel
# 4              4         Albania            Biodiesel - Imports  Biodiesel
# ...          ...             ...                            ...        ...
# 8563        8563         Uruguay  Biodiesel - Final consumption  Biodiesel
# 8564        8564         Uruguay  Biodiesel - Final consumption  Biodiesel
# 8565        8565         Uruguay  Biodiesel - Final consumption  Biodiesel
# 8566        8566         Uruguay  Biodiesel - Final consumption  Biodiesel
# 8567        8567         Uruguay  Biodiesel - Final consumption  Biodiesel
#
#             Transaction  Year                    Unit  Quantity  \
# ...

# %%
FILE_NAME = 'Biogases'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 277778*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area       Commodity - Transaction Commodity  \
# 0               0       Australia         Biogases - Production  Biogases
# 1               1       Australia         Biogases - Production  Biogases
# 2               2       Australia         Biogases - Production  Biogases
# 3               3       Australia         Biogases - Production  Biogases
# 4               4       Australia         Biogases - Production  Biogases
# ...           ...             ...                           ...       ...
# 15986       15986   United States  Biogases - Final consumption  Biogases
# 15987       15987   United States  Biogases - Final consumption  Biogases
# 15988       15988   United States  Biogases - Final consumption  Biogases
# 15989       15989   United States  Biogases - Final consumption  Biogases
# 15990       15990   United States  Biogases - Final consumption  Biogases
#
#              Transaction  Year        Unit   Quantity  Quantity Footnotes  \
# ...

# %%
FILE_NAME = 'Biogasoline'
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 26.8 TJ/(thousand of tons) --> 7.22e6 kWh/(thousand of tons)
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 7.22e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0 Country or Area          Commodity - Transaction  \
# 0              0       Argentina         Biogasoline - production
# 1              1       Argentina         Biogasoline - production
# 2              2       Argentina         Biogasoline - production
# 3              3       Argentina         Biogasoline - production
# 4              4       Argentina         Biogasoline - production
# ...          ...             ...                              ...
# 6438        6438        Zimbabwe  Biogasoline - Final consumption
# 6439        6439        Zimbabwe  Biogasoline - Final consumption
# 6440        6440        Zimbabwe  Biogasoline - Final consumption
# 6441        6441        Zimbabwe  Biogasoline - Final consumption
# 6442        6442        Zimbabwe  Biogasoline - Final consumption
#
#         Commodity        Transaction  Year                    Unit  Quantity  \
# 0     Biogasoline         production  2020  Metric tons,  thousand  1128.284
# ...

# %%
FILE_NAME = 'Bitumen'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 40.20 TJ/(thousand of tons) --> 11.1e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 11.1e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area      Commodity - Transaction Commodity  \
# 0               0     Afghanistan         Bitumen - Production   Bitumen
# 1               1     Afghanistan         Bitumen - Production   Bitumen
# 2               2     Afghanistan         Bitumen - Production   Bitumen
# 3               3     Afghanistan         Bitumen - Production   Bitumen
# 4               4     Afghanistan         Bitumen - Production   Bitumen
# ...           ...             ...                          ...       ...
# 25752       25752        Zimbabwe  Bitumen - Final consumption   Bitumen
# 25753       25753        Zimbabwe  Bitumen - Final consumption   Bitumen
# 25754       25754        Zimbabwe  Bitumen - Final consumption   Bitumen
# 25755       25755        Zimbabwe  Bitumen - Final consumption   Bitumen
# 25756       25756        Zimbabwe  Bitumen - Final consumption   Bitumen
#
#              Transaction  Year                    Unit  Quantity  \
# ...

# %%
FILE_NAME = 'Black Liquor'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 277778*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0 Country or Area           Commodity - Transaction  \
# 0              0       Australia         Black Liquor - Production
# 1              1       Australia         Black Liquor - Production
# 2              2       Australia         Black Liquor - Production
# 3              3       Australia         Black Liquor - Production
# 4              4       Australia         Black Liquor - Production
# ...          ...             ...                               ...
# 5254        5254         Uruguay  Black Liquor - Final consumption
# 5255        5255         Uruguay  Black Liquor - Final consumption
# 5256        5256         Uruguay  Black Liquor - Final consumption
# 5257        5257         Uruguay  Black Liquor - Final consumption
# 5258        5258         Uruguay  Black Liquor - Final consumption
#
#          Commodity        Transaction  Year        Unit  Quantity  \
# 0     Black Liquor         Production  2019  Terajoules   15438.0
# ...

# %%
FILE_NAME = 'Blast Furnace Gas'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 277778*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area                Commodity - Transaction  \
# 0               0         Algeria         Blast Furnace Gas - Production
# 1               1         Algeria         Blast Furnace Gas - Production
# 2               2         Algeria         Blast Furnace Gas - Production
# 3               3         Algeria         Blast Furnace Gas - Production
# 4               4         Algeria         Blast Furnace Gas - Production
# ...           ...             ...                                    ...
# 14478       14478        Zimbabwe  Blast furnace gas - final consumption
# 14479       14479        Zimbabwe  Blast furnace gas - final consumption
# 14480       14480        Zimbabwe  Blast furnace gas - final consumption
# 14481       14481        Zimbabwe  Blast furnace gas - final consumption
# 14482       14482        Zimbabwe  Blast furnace gas - final consumption
#
#                Commodity        Transaction  Year        Unit  Quantity  \
# ...

# %%
FILE_NAME = 'Brown coal'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 14 TJ/(thousand of tons) --> 3.88e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 3.88e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area  \
# 0               0         Albania
# 1               1         Albania
# 2               2         Albania
# 3               3         Albania
# 4               4         Albania
# ...           ...             ...
# 25135       25135          Zambia
# 25136       25136        Zimbabwe
# 25137       25137        Zimbabwe
# 25138       25138        Zimbabwe
# 25139       25139        Zimbabwe
#
#                              Commodity - Transaction           Commodity  \
# 0                            Brown coal - production          Brown coal
# 1                            Brown coal - production          Brown coal
# 2                            Brown coal - production          Brown coal
# 3                            Brown coal - production          Brown coal
# 4                            Brown coal - production          Brown coal
# ...                                              ...                 ...
# ...

# %%
FILE_NAME = 'Brown Coal Briquettes'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 20.7 TJ/(thousand of tons) --> 5.5e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 5.5e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0           Country or Area  \
# 0              0                   Albania
# 1              1                   Albania
# 2              2                   Albania
# 3              3                   Albania
# 4              4                   Albania
# ...          ...                       ...
# 7079        7079  Yugoslavia, SFR (former)
# 7080        7080  Yugoslavia, SFR (former)
# 7081        7081  Yugoslavia, SFR (former)
# 7082        7082  Yugoslavia, SFR (former)
# 7083        7083  Yugoslavia, SFR (former)
#
#                                 Commodity - Transaction  \
# 0                    Brown coal briquettes - production
# 1                    Brown coal briquettes - production
# 2                    Brown coal briquettes - production
# 3                    Brown coal briquettes - production
# 4                    Brown coal briquettes - production
# ...                                                 ...
# ...

# %%
FILE_NAME = 'Charcoal'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 29.5 TJ/(thousand of tons) --> 8.05e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 8.05e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area       Commodity - Transaction Commodity  \
# 0               0     Afghanistan         Charcoal - Production  Charcoal
# 1               1     Afghanistan         Charcoal - Production  Charcoal
# 2               2     Afghanistan         Charcoal - Production  Charcoal
# 3               3     Afghanistan         Charcoal - Production  Charcoal
# 4               4     Afghanistan         Charcoal - Production  Charcoal
# ...           ...             ...                           ...       ...
# 35108       35108        Zimbabwe  Charcoal - Final consumption  Charcoal
# 35109       35109        Zimbabwe  Charcoal - Final consumption  Charcoal
# 35110       35110        Zimbabwe  Charcoal - Final consumption  Charcoal
# 35111       35111        Zimbabwe  Charcoal - Final consumption  Charcoal
# 35112       35112        Zimbabwe  Charcoal - Final consumption  Charcoal
#
#              Transaction  Year                    Unit  Quantity  \
# ...

# %%
FILE_NAME = 'Coal Tar'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 28 TJ/(thousand of tons) --> 7.77e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 7.77e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0 Country or Area         Commodity - Transaction Commodity  \
# 0              0         Armenia              Coal Tar - Imports  Coal Tar
# 1              1         Armenia  Coal Tar - Total energy supply  Coal Tar
# 2              2       Australia           Coal Tar - Production  Coal Tar
# 3              3       Australia           Coal Tar - Production  Coal Tar
# 4              4       Australia           Coal Tar - Production  Coal Tar
# ...          ...             ...                             ...       ...
# 3335        3335      Uzbekistan  Coal Tar - Total energy supply  Coal Tar
# 3336        3336      Uzbekistan  Coal Tar - Total energy supply  Coal Tar
# 3337        3337      Uzbekistan  Coal Tar - Total energy supply  Coal Tar
# 3338        3338      Uzbekistan  Coal Tar - Total energy supply  Coal Tar
# 3339        3339      Uzbekistan  Coal Tar - Total energy supply  Coal Tar
#
# ...

# %%
FILE_NAME = 'Coke Oven Coke'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 28.2 TJ/(thousand of tons) --> 7.77e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 7.77e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area             Commodity - Transaction  \
# 0               0     Afghanistan         Coke oven coke - production
# 1               1     Afghanistan         Coke oven coke - production
# 2               2     Afghanistan         Coke oven coke - production
# 3               3     Afghanistan         Coke oven coke - production
# 4               4     Afghanistan         Coke oven coke - production
# ...           ...             ...                                 ...
# 27404       27404        Zimbabwe  Coke-oven coke - final consumption
# 27405       27405        Zimbabwe  Coke-oven coke - final consumption
# 27406       27406        Zimbabwe  Coke-oven coke - final consumption
# 27407       27407        Zimbabwe  Coke-oven coke - final consumption
# 27408       27408        Zimbabwe  Coke-oven coke - final consumption
#
#             Commodity        Transaction  Year                    Unit  \
# ...

# %%
FILE_NAME = 'Coke Oven Gas'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 277778*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area            Commodity - Transaction  \
# 0               0         Algeria         Coke Oven Gas - Production
# 1               1         Algeria         Coke Oven Gas - Production
# 2               2         Algeria         Coke Oven Gas - Production
# 3               3         Algeria         Coke Oven Gas - Production
# 4               4         Algeria         Coke Oven Gas - Production
# ...           ...             ...                                ...
# 14433       14433        Zimbabwe  Coke Oven Gas - Final consumption
# 14434       14434        Zimbabwe  Coke Oven Gas - Final consumption
# 14435       14435        Zimbabwe  Coke Oven Gas - Final consumption
# 14436       14436        Zimbabwe  Coke Oven Gas - Final consumption
# 14437       14437        Zimbabwe  Coke Oven Gas - Final consumption
#
#            Commodity        Transaction  Year        Unit  Quantity  \
# 0      Coke Oven Gas         Production  2015  Terajoules       0.0
# ...

# %%
FILE_NAME = 'Coking coal'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 28.2 TJ/(thousand of tons) --> 7.77e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 7.77e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0 Country or Area            Commodity - Transaction  \
# 0              0         Algeria              Coking coal - imports
# 1              1         Algeria              Coking coal - imports
# 2              2         Algeria              Coking coal - imports
# 3              3         Algeria              Coking coal - imports
# 4              4         Algeria              Coking coal - imports
# ...          ...             ...                                ...
# 8181        8181        Zimbabwe  Coking coal - total energy supply
# 8182        8182        Zimbabwe    Coking coal - final consumption
# 8183        8183        Zimbabwe    Coking coal - final consumption
# 8184        8184        Zimbabwe    Coking coal - final consumption
# 8185        8185        Zimbabwe    Coking coal - final consumption
#
#         Commodity          Transaction  Year                    Unit  \
# 0     Coking coal              imports  2019  Metric tons,  thousand
# ...

# %%
FILE_NAME = 'Conventional crude oil'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 42.3 TJ/(thousand of tons) --> 11.7e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 11.7e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area  \
# 0               0     Afghanistan
# 1               1     Afghanistan
# 2               2     Afghanistan
# 3               3     Afghanistan
# 4               4     Afghanistan
# ...           ...             ...
# 33401       33401          Zambia
# 33402       33402          Zambia
# 33403       33403          Zambia
# 33404       33404        Zimbabwe
# 33405       33405        Zimbabwe
#
#                             Commodity - Transaction               Commodity  \
# 0                  Conventional crude oil - imports  Conventional crude oil
# 1                  Conventional crude oil - imports  Conventional crude oil
# 2                  Conventional crude oil - imports  Conventional crude oil
# 3                  Conventional crude oil - imports  Conventional crude oil
# 4                  Conventional crude oil - imports  Conventional crude oil
# ...                                             ...                     ...
# ...

# %%
FILE_NAME = 'Ethane'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 46.4 TJ/(thousand of tons) --> 12.7e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 12.7e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0 Country or Area     Commodity - Transaction Commodity  \
# 0              0         Algeria         Ethane - Production    Ethane
# 1              1         Algeria         Ethane - Production    Ethane
# 2              2         Algeria         Ethane - Production    Ethane
# 3              3         Algeria         Ethane - Production    Ethane
# 4              4         Algeria         Ethane - Production    Ethane
# ...          ...             ...                         ...       ...
# 2542        2542   United States  Ethane - Final consumption    Ethane
# 2543        2543   United States  Ethane - Final consumption    Ethane
# 2544        2544   United States  Ethane - Final consumption    Ethane
# 2545        2545   United States  Ethane - Final consumption    Ethane
# 2546        2546   United States  Ethane - Final consumption    Ethane
#
#             Transaction  Year                    Unit  Quantity  \
# ...

# %%
FILE_NAME = 'Fuel Oil'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 40.4 TJ/(thousand of tons) --> 11.1e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 11.1e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area       Commodity - Transaction Commodity  \
# 0               0     Afghanistan         Fuel oil - Production  Fuel oil
# 1               1     Afghanistan         Fuel oil - Production  Fuel oil
# 2               2     Afghanistan         Fuel oil - Production  Fuel oil
# 3               3     Afghanistan         Fuel oil - Production  Fuel oil
# 4               4     Afghanistan         Fuel oil - Production  Fuel oil
# ...           ...             ...                           ...       ...
# 97520       97520          Zambia  Fuel oil - Final consumption  Fuel oil
# 97521       97521          Zambia  Fuel oil - Final consumption  Fuel oil
# 97522       97522          Zambia  Fuel oil - Final consumption  Fuel oil
# 97523       97523          Zambia  Fuel oil - Final consumption  Fuel oil
# 97524       97524          Zambia  Fuel oil - Final consumption  Fuel oil
#
#              Transaction  Year                    Unit  Quantity  \
# ...

# %%
FILE_NAME = 'Fuelwood'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 9.14 TJ/(thousand of m^3) --> 2.5e6 kWh/(thousand of m^3)
df['Conversion_in_kWh'] = 2.5e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area       Commodity - Transaction Commodity  \
# 0               0     Afghanistan         Fuelwood - Production  Fuelwood
# 1               1     Afghanistan         Fuelwood - Production  Fuelwood
# 2               2     Afghanistan         Fuelwood - Production  Fuelwood
# 3               3     Afghanistan         Fuelwood - Production  Fuelwood
# 4               4     Afghanistan         Fuelwood - Production  Fuelwood
# ...           ...             ...                           ...       ...
# 70074       70074        Zimbabwe  Fuelwood - Final consumption  Fuelwood
# 70075       70075        Zimbabwe  Fuelwood - Final consumption  Fuelwood
# 70076       70076        Zimbabwe  Fuelwood - Final consumption  Fuelwood
# 70077       70077        Zimbabwe  Fuelwood - Final consumption  Fuelwood
# 70078       70078        Zimbabwe  Fuelwood - Final consumption  Fuelwood
#
#              Transaction  Year                    Unit      Quantity  \
# ...

# %%
FILE_NAME = 'Gas coke'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://www150.statcan.gc.ca/n1/pub/57-601-x/00105/4173282-eng.htm --> 18.6 TJ/(thousand of tons) --> 5e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 5e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#      Unnamed: 0           Country or Area         Commodity - Transaction  \
# 0             0               Afghanistan              Gas coke - imports
# 1             1               Afghanistan              Gas coke - imports
# 2             2               Afghanistan              Gas coke - imports
# 3             3               Afghanistan              Gas coke - imports
# 4             4               Afghanistan              Gas coke - imports
# ..          ...                       ...                             ...
# 445         445                   Uruguay  Gas coke - Total energy supply
# 446         446  Yugoslavia, SFR (former)           Gas coke - production
# 447         447  Yugoslavia, SFR (former)           Gas coke - production
# 448         448  Yugoslavia, SFR (former)  Gas coke - Total energy supply
# 449         449  Yugoslavia, SFR (former)  Gas coke - Total energy supply
#
#     Commodity          Transaction  Year                    Unit  Quantity  \
# ...

# %%
FILE_NAME = 'Gas Oil and Diesel Oil'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 43 TJ/(thousand of tons) --> 11.9e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 11.9e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0     Country or Area              Commodity - Transaction  \
# 0               0         Afghanistan     Gas Oil/ Diesel Oil - Production
# 1               1         Afghanistan     Gas Oil/ Diesel Oil - Production
# 2               2         Afghanistan     Gas Oil/ Diesel Oil - Production
# 3               3         Afghanistan     Gas Oil/ Diesel Oil - Production
# 4               4         Afghanistan     Gas Oil/ Diesel Oil - Production
# ...           ...                 ...                                  ...
# 99995       99995  Russian Federation  Gas Oil/ Diesel Oil - Stock changes
# 99996       99996  Russian Federation  Gas Oil/ Diesel Oil - Stock changes
# 99997       99997  Russian Federation  Gas Oil/ Diesel Oil - Stock changes
# 99998       99998  Russian Federation  Gas Oil/ Diesel Oil - Stock changes
# 99999       99999  Russian Federation  Gas Oil/ Diesel Oil - Stock changes
#
# ...

# %%
FILE_NAME = 'Gasoline-type jet fuel'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 44.3 TJ/(thousand of tons) --> 12.2e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 12.2e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0 Country or Area  \
# 0              0          Angola
# 1              1          Angola
# 2              2          Angola
# 3              3          Angola
# 4              4          Angola
# ...          ...             ...
# 1448        1448        Viet Nam
# 1449        1449        Viet Nam
# 1450        1450        Viet Nam
# 1451        1451        Viet Nam
# 1452        1452        Viet Nam
#
#                            Commodity - Transaction               Commodity  \
# 0              Gasoline-type jet fuel - Production  Gasoline-type jet fuel
# 1              Gasoline-type jet fuel - Production  Gasoline-type jet fuel
# 2              Gasoline-type jet fuel - Production  Gasoline-type jet fuel
# 3              Gasoline-type jet fuel - Production  Gasoline-type jet fuel
# 4              Gasoline-type jet fuel - Production  Gasoline-type jet fuel
# ...                                            ...                     ...
# ...

# %%
FILE_NAME = 'Gasworks Gas'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 277778*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0           Country or Area  \
# 0              0                 Australia
# 1              1                 Australia
# 2              2                 Australia
# 3              3                 Australia
# 4              4                 Australia
# ...          ...                       ...
# 7155        7155  Yugoslavia, SFR (former)
# 7156        7156  Yugoslavia, SFR (former)
# 7157        7157  Yugoslavia, SFR (former)
# 7158        7158  Yugoslavia, SFR (former)
# 7159        7159  Yugoslavia, SFR (former)
#
#                          Commodity - Transaction     Commodity  \
# 0     Gasworks Gas - Receipts from other sources  Gasworks Gas
# 1     Gasworks Gas - Receipts from other sources  Gasworks Gas
# 2     Gasworks Gas - Receipts from other sources  Gasworks Gas
# 3     Gasworks Gas - Receipts from other sources  Gasworks Gas
# 4     Gasworks Gas - Receipts from other sources  Gasworks Gas
# ...

# %%
FILE_NAME = 'Hard coal'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 25.8 TJ/(thousand of tons) --> 6.94e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 6.94e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area        Commodity - Transaction  Commodity  \
# 0               0     Afghanistan         Hard coal - production  Hard coal
# 1               1     Afghanistan         Hard coal - production  Hard coal
# 2               2     Afghanistan         Hard coal - production  Hard coal
# 3               3     Afghanistan         Hard coal - production  Hard coal
# 4               4     Afghanistan         Hard coal - production  Hard coal
# ...           ...             ...                            ...        ...
# 54776       54776        Zimbabwe  Hard coal - final consumption  Hard coal
# 54777       54777        Zimbabwe  Hard coal - final consumption  Hard coal
# 54778       54778        Zimbabwe  Hard coal - final consumption  Hard coal
# 54779       54779        Zimbabwe  Hard coal - final consumption  Hard coal
# 54780       54780        Zimbabwe  Hard coal - final consumption  Hard coal
#
# ...

# %%
FILE_NAME = 'Heat'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 277778*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0           Country or Area  \
# 0               0                   Albania
# 1               1                   Albania
# 2               2                   Albania
# 3               3                   Albania
# 4               4                   Albania
# ...           ...                       ...
# 40363       40363  Yugoslavia, SFR (former)
# 40364       40364  Yugoslavia, SFR (former)
# 40365       40365  Yugoslavia, SFR (former)
# 40366       40366  Yugoslavia, SFR (former)
# 40367       40367  Yugoslavia, SFR (former)
#
#                      Commodity - Transaction        Commodity  \
# 0                    Heat - Gross production             Heat
# 1                    Heat - Gross production             Heat
# 2                    Heat - Gross production             Heat
# 3                    Heat - Gross production             Heat
# 4                    Heat - Gross production             Heat
# ...

# %%
FILE_NAME = 'Industrial waste'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 277778*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area               Commodity - Transaction  \
# 0               0       Australia         Industrial Waste - Production
# 1               1       Australia         Industrial Waste - Production
# 2               2       Australia         Industrial Waste - Production
# 3               3       Australia         Industrial Waste - Production
# 4               4       Australia         Industrial Waste - Production
# ...           ...             ...                                   ...
# 11734       11734         Uruguay  Industrial waste - Final consumption
# 11735       11735         Uruguay  Industrial waste - Final consumption
# 11736       11736         Uruguay  Industrial waste - Final consumption
# 11737       11737         Uruguay  Industrial waste - Final consumption
# 11738       11738         Uruguay  Industrial waste - Final consumption
#
#               Commodity        Transaction  Year        Unit  Quantity  \
# ...

# %%
FILE_NAME = 'Kerosene-type Jet Fuel'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 44.1 TJ/(thousand of tons) --> 12.2e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 12.2e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area  \
# 0               0     Afghanistan
# 1               1     Afghanistan
# 2               2     Afghanistan
# 3               3     Afghanistan
# 4               4     Afghanistan
# ...           ...             ...
# 45323       45323        Zimbabwe
# 45324       45324        Zimbabwe
# 45325       45325        Zimbabwe
# 45326       45326        Zimbabwe
# 45327       45327        Zimbabwe
#
#                             Commodity - Transaction               Commodity  \
# 0                  Kerosene-type Jet Fuel - Imports  Kerosene-type Jet Fuel
# 1                  Kerosene-type Jet Fuel - Imports  Kerosene-type Jet Fuel
# 2                  Kerosene-type Jet Fuel - Imports  Kerosene-type Jet Fuel
# 3                  Kerosene-type Jet Fuel - Imports  Kerosene-type Jet Fuel
# 4                  Kerosene-type Jet Fuel - Imports  Kerosene-type Jet Fuel
# ...                                             ...                     ...
# ...

# %%
FILE_NAME = 'Lignite'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://www150.statcan.gc.ca/n1/pub/57-601-x/00105/4173282-eng.htm --> 15 TJ/(thousand of tons) --> 4.17e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 4.17e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area      Commodity - Transaction Commodity  \
# 0               0         Albania         Lignite - Production   Lignite
# 1               1         Albania         Lignite - Production   Lignite
# 2               2         Albania         Lignite - Production   Lignite
# 3               3         Albania         Lignite - Production   Lignite
# 4               4         Albania         Lignite - Production   Lignite
# ...           ...             ...                          ...       ...
# 17316       17316      Uzbekistan  Lignite - Final consumption   Lignite
# 17317       17317      Uzbekistan  Lignite - Final consumption   Lignite
# 17318       17318      Uzbekistan  Lignite - Final consumption   Lignite
# 17319       17319      Uzbekistan  Lignite - Final consumption   Lignite
# 17320       17320      Uzbekistan  Lignite - Final consumption   Lignite
#
#              Transaction  Year                    Unit  Quantity  \
# ...

# %%
FILE_NAME = 'Liquified Petroleum Gas'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 47.3 TJ/(thousand of tons) --> 13e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 13e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area  \
# 0               0     Afghanistan
# 1               1     Afghanistan
# 2               2     Afghanistan
# 3               3     Afghanistan
# 4               4     Afghanistan
# ...           ...             ...
# 83125       83125        Zimbabwe
# 83126       83126        Zimbabwe
# 83127       83127        Zimbabwe
# 83128       83128        Zimbabwe
# 83129       83129        Zimbabwe
#
#                                  Commodity - Transaction  \
# 0                Liquefied petroleum gas (LPG) - Imports
# 1                Liquefied petroleum gas (LPG) - Imports
# 2                Liquefied petroleum gas (LPG) - Imports
# 3                Liquefied petroleum gas (LPG) - Imports
# 4                Liquefied petroleum gas (LPG) - Imports
# ...                                                  ...
# 83125  Liquefied petroleum gas (LPG) - Final consumption
# 83126  Liquefied petroleum gas (LPG) - Final consumption
# ...

# %%
FILE_NAME = 'Lubricants'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 40.2 TJ/(thousand of tons) --> 11.1e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 11.1e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0           Country or Area           Commodity - Transaction  \
# 0               0               Afghanistan              Lubricants - Imports
# 1               1               Afghanistan              Lubricants - Imports
# 2               2               Afghanistan              Lubricants - Imports
# 3               3               Afghanistan              Lubricants - Imports
# 4               4               Afghanistan              Lubricants - Imports
# ...           ...                       ...                               ...
# 26813       26813  Yugoslavia, SFR (former)      Lubricants - Non-energy uses
# 26814       26814  Yugoslavia, SFR (former)  Lubricants - Total energy supply
# 26815       26815  Yugoslavia, SFR (former)  Lubricants - Total energy supply
# 26816       26816  Yugoslavia, SFR (former)    Lubricants - Final consumption
# 26817       26817  Yugoslavia, SFR (former)    Lubricants - Final consumption
#
# ...

# %%
FILE_NAME = 'Motor Gasoline'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 44.3 TJ/(thousand of tons) --> 12.2e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 12.2e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area             Commodity - Transaction  \
# 0               0     Afghanistan         Motor Gasoline - Production
# 1               1     Afghanistan         Motor Gasoline - Production
# 2               2     Afghanistan         Motor Gasoline - Production
# 3               3     Afghanistan         Motor Gasoline - Production
# 4               4     Afghanistan         Motor Gasoline - Production
# ...           ...             ...                                 ...
# 69922       69922        Zimbabwe  Motor Gasoline - Final consumption
# 69923       69923        Zimbabwe  Motor Gasoline - Final consumption
# 69924       69924        Zimbabwe  Motor Gasoline - Final consumption
# 69925       69925        Zimbabwe  Motor Gasoline - Final consumption
# 69926       69926        Zimbabwe  Motor Gasoline - Final consumption
#
#             Commodity        Transaction  Year                    Unit  \
# ...

# %%
FILE_NAME = 'Municipal Wastes'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 277778*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0 Country or Area               Commodity - Transaction  \
# 0              0         Andorra         Municipal Wastes - Production
# 1              1         Andorra         Municipal Wastes - Production
# 2              2         Andorra         Municipal Wastes - Production
# 3              3         Andorra         Municipal Wastes - Production
# 4              4         Andorra         Municipal Wastes - Production
# ...          ...             ...                                   ...
# 8989        8989   United States  Municipal wastes - final consumption
# 8990        8990   United States  Municipal wastes - final consumption
# 8991        8991   United States  Municipal wastes - final consumption
# 8992        8992   United States  Municipal wastes - final consumption
# 8993        8993   United States  Municipal wastes - final consumption
#
#              Commodity        Transaction  Year        Unit   Quantity  \
# ...

# %%
FILE_NAME = 'Natural Gas (including LNG)'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 277778*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0           Country or Area  \
# 0               0               Afghanistan
# 1               1               Afghanistan
# 2               2               Afghanistan
# 3               3               Afghanistan
# 4               4               Afghanistan
# ...           ...                       ...
# 84782       84782  Yugoslavia, SFR (former)
# 84783       84783  Yugoslavia, SFR (former)
# 84784       84784  Yugoslavia, SFR (former)
# 84785       84785  Yugoslavia, SFR (former)
# 84786       84786  Yugoslavia, SFR (former)
#
#                                  Commodity - Transaction  \
# 0               Natural gas (including LNG) - production
# 1               Natural gas (including LNG) - production
# 2               Natural gas (including LNG) - production
# 3               Natural gas (including LNG) - production
# 4               Natural gas (including LNG) - production
# ...                                                  ...
# ...

# %%
FILE_NAME = 'Natural Gas Liquid'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 44.2 TJ/(thousand of tons) --> 12.2e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 12.2e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0           Country or Area  \
# 0               0               Afghanistan
# 1               1               Afghanistan
# 2               2               Afghanistan
# 3               3               Afghanistan
# 4               4               Afghanistan
# ...           ...                       ...
# 10666       10666  Yugoslavia, SFR (former)
# 10667       10667  Yugoslavia, SFR (former)
# 10668       10668  Yugoslavia, SFR (former)
# 10669       10669  Yugoslavia, SFR (former)
# 10670       10670  Yugoslavia, SFR (former)
#
#                           Commodity - Transaction            Commodity  \
# 0                Natural gas liquids - Production  Natural gas liquids
# 1                Natural gas liquids - Production  Natural gas liquids
# 2                Natural gas liquids - Production  Natural gas liquids
# 3            Natural gas liquids - Transformation  Natural gas liquids
# 4            Natural gas liquids - Transformation  Natural gas liquids
# ...

# %%
FILE_NAME = 'Oil Shale and Oil Sands'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 8.9 TJ/(thousand of tons) --> 2.2e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 2.2e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#      Unnamed: 0 Country or Area  \
# 0             0         Albania
# 1             1         Albania
# 2             2         Albania
# 3             3         Albania
# 4             4         Albania
# ..          ...             ...
# 904         904   USSR (former)
# 905         905   USSR (former)
# 906         906   USSR (former)
# 907         907   USSR (former)
# 908         908   USSR (former)
#
#                                Commodity - Transaction  Commodity  \
# 0                               Oil shale - Production  Oil shale
# 1                               Oil shale - Production  Oil shale
# 2                               Oil shale - Production  Oil shale
# 3                               Oil shale - Production  Oil shale
# 4                               Oil shale - Production  Oil shale
# ..                                                 ...        ...
# 904  Oil shale - Transformation in electricity, CHP...  Oil shale
# ...

# %%
FILE_NAME = 'Other bituminous coal'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 40.2 TJ/(thousand of tons) --> 11.1e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 11.1e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area                    Commodity - Transaction  \
# 0               0         Albania         Other bituminous coal - production
# 1               1         Albania         Other bituminous coal - production
# 2               2         Albania         Other bituminous coal - production
# 3               3         Albania         Other bituminous coal - production
# 4               4         Albania         Other bituminous coal - production
# ...           ...             ...                                        ...
# 32688       32688        Zimbabwe  Other bituminous coal - final consumption
# 32689       32689        Zimbabwe  Other bituminous coal - final consumption
# 32690       32690        Zimbabwe  Other bituminous coal - final consumption
# 32691       32691        Zimbabwe  Other bituminous coal - final consumption
# 32692       32692        Zimbabwe  Other bituminous coal - final consumption
#
# ...

# %%
FILE_NAME = 'Other coal products'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 20 TJ/(thousand of tons) --> 5.55e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 5.55e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#      Unnamed: 0 Country or Area                    Commodity - Transaction  \
# 0             0         Armenia              Other coal products - Imports
# 1             1         Armenia  Other coal products - Total energy supply
# 2             2         Bermuda              Other coal products - Imports
# 3             3         Bermuda              Other coal products - Imports
# 4             4         Bermuda              Other coal products - Imports
# ..          ...             ...                                        ...
# 212         212          Guyana  Other coal products - Total energy supply
# 213         213          Guyana  Other coal products - Total energy supply
# 214         214          Guyana  Other coal products - Total energy supply
# 215         215          Guyana  Other coal products - Total energy supply
# 216         216          Guyana  Other coal products - Total energy supply
#
# ...

# %%
FILE_NAME = 'Other hydrocarbons'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 36 TJ/(thousand of tons) --> 10e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 10e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0            Country or Area  \
# 0              0                  Australia
# 1              1                  Australia
# 2              2                  Australia
# 3              3                  Australia
# 4              4                  Australia
# ...          ...                        ...
# 2784        2784  Venezuela (Bolivar. Rep.)
# 2785        2785  Venezuela (Bolivar. Rep.)
# 2786        2786  Venezuela (Bolivar. Rep.)
# 2787        2787  Venezuela (Bolivar. Rep.)
# 2788        2788  Venezuela (Bolivar. Rep.)
#
#                                Commodity - Transaction           Commodity  \
# 0     Other hydrocarbons - receipts from other sources  Other hydrocarbons
# 1     Other hydrocarbons - receipts from other sources  Other hydrocarbons
# 2     Other hydrocarbons - receipts from other sources  Other hydrocarbons
# 3     Other hydrocarbons - receipts from other sources  Other hydrocarbons
# ...

# %%
FILE_NAME = 'Other kerosene'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 43.8 TJ/(thousand of tons) --> 11.8e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 11.8e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area             Commodity - Transaction  \
# 0               0     Afghanistan            Other kerosene - Imports
# 1               1     Afghanistan            Other kerosene - Imports
# 2               2     Afghanistan            Other kerosene - Imports
# 3               3     Afghanistan            Other kerosene - Imports
# 4               4     Afghanistan            Other kerosene - Imports
# ...           ...             ...                                 ...
# 54076       54076        Zimbabwe  Other kerosene - Final consumption
# 54077       54077        Zimbabwe  Other kerosene - Final consumption
# 54078       54078        Zimbabwe  Other kerosene - Final consumption
# 54079       54079        Zimbabwe  Other kerosene - Final consumption
# 54080       54080        Zimbabwe  Other kerosene - Final consumption
#
#             Commodity        Transaction  Year                    Unit  \
# ...

# %%
FILE_NAME = 'Other liquid biofuels'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 27.4 TJ/(thousand of tons) --> 7.5e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 7.5e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0 Country or Area                      Commodity - Transaction  \
# 0              0         Austria           Other liquid biofuels - Production
# 1              1         Austria           Other liquid biofuels - Production
# 2              2         Austria           Other liquid biofuels - Production
# 3              3         Austria           Other liquid biofuels - Production
# 4              4         Austria           Other liquid biofuels - Production
# ...          ...             ...                                          ...
# 2661        2661         Vanuatu  Other liquid biofuels - Total energy supply
# 2662        2662         Vanuatu  Other liquid biofuels - Total energy supply
# 2663        2663         Vanuatu  Other liquid biofuels - Total energy supply
# 2664        2664         Vanuatu  Other liquid biofuels - Total energy supply
# 2665        2665         Vanuatu  Other liquid biofuels - Total energy supply
#
# ...

# %%
FILE_NAME = 'Other oil products n.e.c. '
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 40.2 TJ/(thousand of tons) --> 11.1e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 11.1e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area  \
# 0               0         Albania
# 1               1         Albania
# 2               2         Albania
# 3               3         Albania
# 4               4         Albania
# ...           ...             ...
# 28430       28430        Zimbabwe
# 28431       28431        Zimbabwe
# 28432       28432        Zimbabwe
# 28433       28433        Zimbabwe
# 28434       28434        Zimbabwe
#
#                              Commodity - Transaction  \
# 0             Other oil products n.e.c. - Production
# 1             Other oil products n.e.c. - Production
# 2             Other oil products n.e.c. - Production
# 3             Other oil products n.e.c. - Production
# 4             Other oil products n.e.c. - Production
# ...                                              ...
# 28430  Other oil products n.e.c. - Final consumption
# 28431  Other oil products n.e.c. - Final consumption
# 28432  Other oil products n.e.c. - Final consumption
# ...

# %%
FILE_NAME = 'Other recovered gases'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 277778*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0 Country or Area                    Commodity - Transaction  \
# 0              0         Austria         Other recovered gases - Production
# 1              1         Austria         Other recovered gases - Production
# 2              2         Austria         Other recovered gases - Production
# 3              3         Austria         Other recovered gases - Production
# 4              4         Austria         Other recovered gases - Production
# ...          ...             ...                                        ...
# 3452        3452         Ukraine  Other recovered gases - Final consumption
# 3453        3453         Ukraine  Other recovered gases - Final consumption
# 3454        3454         Ukraine  Other recovered gases - Final consumption
# 3455        3455         Ukraine  Other recovered gases - Final consumption
# 3456        3456         Ukraine  Other recovered gases - Final consumption
#
# ...

# %%
FILE_NAME = 'Other Vegetal Material and Residues'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 277778*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area            Commodity - Transaction  \
# 0               0          Angola         Vegetal waste - Production
# 1               1          Angola         Vegetal waste - Production
# 2               2          Angola         Vegetal waste - Production
# 3               3          Angola         Vegetal waste - Production
# 4               4          Angola         Vegetal waste - Production
# ...           ...             ...                                ...
# 20350       20350        Zimbabwe  Vegetal waste - Final consumption
# 20351       20351        Zimbabwe  Vegetal waste - Final consumption
# 20352       20352        Zimbabwe  Vegetal waste - Final consumption
# 20353       20353        Zimbabwe  Vegetal waste - Final consumption
# 20354       20354        Zimbabwe  Vegetal waste - Final consumption
#
#            Commodity        Transaction  Year        Unit    Quantity  \
# ...

# %%
FILE_NAME = 'Paraffin waxes'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 40.2 TJ/(thousand of tons) --> 11.1e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 11.1e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0 Country or Area                    Commodity - Transaction  \
# 0              0     Afghanistan                   Paraffin waxes - Imports
# 1              1     Afghanistan                   Paraffin waxes - Imports
# 2              2     Afghanistan                   Paraffin waxes - Imports
# 3              3     Afghanistan  Paraffin waxes - Final energy consumption
# 4              4     Afghanistan  Paraffin waxes - Final energy consumption
# ...          ...             ...                                        ...
# 9561        9561        Zimbabwe         Paraffin waxes - Final consumption
# 9562        9562        Zimbabwe         Paraffin waxes - Final consumption
# 9563        9563        Zimbabwe         Paraffin waxes - Final consumption
# 9564        9564        Zimbabwe         Paraffin waxes - Final consumption
# 9565        9565        Zimbabwe         Paraffin waxes - Final consumption
#
# ...

# %%
FILE_NAME = 'Patent fuel'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 20.7 TJ/(thousand of tons) --> 5.55e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 5.55e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0           Country or Area            Commodity - Transaction  \
# 0              0               Afghanistan           Patent fuel - production
# 1              1               Afghanistan           Patent fuel - production
# 2              2               Afghanistan           Patent fuel - production
# 3              3               Afghanistan  Patent fuel - Total energy supply
# 4              4               Afghanistan  Patent fuel - Total energy supply
# ...          ...                       ...                                ...
# 4042        4042                Uzbekistan    Patent fuel - Final consumption
# 4043        4043  Yugoslavia, SFR (former)              Patent fuel - imports
# 4044        4044  Yugoslavia, SFR (former)              Patent fuel - imports
# 4045        4045  Yugoslavia, SFR (former)  Patent fuel - Total energy supply
# 4046        4046  Yugoslavia, SFR (former)  Patent fuel - Total energy supply
#
# ...

# %%
FILE_NAME = 'Peat'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 9.76 TJ/(thousand of tons) --> 2.5e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 2.5e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0 Country or Area                  Commodity - Transaction  \
# 0              0         Albania        Peat (for fuel use) - recoverable
# 1              1         Albania        Peat (for fuel use) - recoverable
# 2              2         Albania        Peat (for fuel use) - recoverable
# 3              3         Albania        Peat (for fuel use) - recoverable
# 4              4         Albania        Peat (for fuel use) - recoverable
# ...          ...             ...                                      ...
# 6482        6482        Viet Nam  Peat (for fuel use) - final consumption
# 6483        6483        Viet Nam  Peat (for fuel use) - final consumption
# 6484        6484        Viet Nam  Peat (for fuel use) - final consumption
# 6485        6485        Viet Nam  Peat (for fuel use) - final consumption
# 6486        6486        Viet Nam  Peat (for fuel use) - final consumption
#
#                 Commodity        Transaction  Year                    Unit  \
# ...

# %%
FILE_NAME = 'Peat Products'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 9.76 TJ/(thousand of tons) --> 2.5e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 2.5e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0 Country or Area  \
# 0              0         Belarus
# 1              1         Belarus
# 2              2         Belarus
# 3              3         Belarus
# 4              4         Belarus
# ...          ...             ...
# 2702        2702   USSR (former)
# 2703        2703   USSR (former)
# 2704        2704   USSR (former)
# 2705        2705   USSR (former)
# 2706        2706   USSR (former)
#
#                                 Commodity - Transaction      Commodity  \
# 0                            Peat products - production  Peat products
# 1                            Peat products - production  Peat products
# 2                            Peat products - production  Peat products
# 3                            Peat products - production  Peat products
# 4                            Peat products - production  Peat products
# ...                                                 ...            ...
# ...

# %%
FILE_NAME = 'Petroleum Coke'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 32.5 TJ/(thousand of tons) --> 8.88e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 8.88e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0           Country or Area  \
# 0               0                   Albania
# 1               1                   Albania
# 2               2                   Albania
# 3               3                   Albania
# 4               4                   Albania
# ...           ...                       ...
# 22625       22625  Yugoslavia, SFR (former)
# 22626       22626  Yugoslavia, SFR (former)
# 22627       22627  Yugoslavia, SFR (former)
# 22628       22628  Yugoslavia, SFR (former)
# 22629       22629  Yugoslavia, SFR (former)
#
#                                  Commodity - Transaction       Commodity  \
# 0                            Petroleum coke - Production  Petroleum coke
# 1                            Petroleum coke - Production  Petroleum coke
# 2                            Petroleum coke - Production  Petroleum coke
# 3                            Petroleum coke - Production  Petroleum coke
# ...

# %%
FILE_NAME = 'Refinery Feedstocks'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 43 TJ/(thousand of tons) --> 11.94e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 11.94e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0            Country or Area  \
# 0              0                  Argentina
# 1              1                  Argentina
# 2              2                  Argentina
# 3              3                  Argentina
# 4              4                  Argentina
# ...          ...                        ...
# 7285        7285  Venezuela (Bolivar. Rep.)
# 7286        7286  Venezuela (Bolivar. Rep.)
# 7287        7287  Venezuela (Bolivar. Rep.)
# 7288        7288  Venezuela (Bolivar. Rep.)
# 7289        7289  Venezuela (Bolivar. Rep.)
#
#                            Commodity - Transaction   Commodity  \
# 0         Feedstocks - Receipts from other sources  Feedstocks
# 1     Feedstocks - transfers and recycled products  Feedstocks
# 2     Feedstocks - transfers and recycled products  Feedstocks
# 3     Feedstocks - transfers and recycled products  Feedstocks
# 4                      Feedstocks - transformation  Feedstocks
# ...

# %%
FILE_NAME = 'Refinery gas'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 49.5 TJ/(thousand of tons) --> 13.6e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 13.6e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area             Commodity - Transaction  \
# 0               0         Albania           Refinery gas - Production
# 1               1         Albania           Refinery gas - Production
# 2               2         Albania           Refinery gas - Production
# 3               3         Albania           Refinery gas - Production
# 4               4         Albania           Refinery gas - Production
# ...           ...             ...                                 ...
# 19322       19322          Zambia  Refinery gas - Total energy supply
# 19323       19323          Zambia  Refinery gas - Total energy supply
# 19324       19324          Zambia  Refinery gas - Total energy supply
# 19325       19325          Zambia  Refinery gas - Total energy supply
# 19326       19326          Zambia  Refinery gas - Total energy supply
#
#           Commodity          Transaction  Year                    Unit  \
# ...

# %%
FILE_NAME = 'Sub-bituminous coal'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://www150.statcan.gc.ca/n1/pub/57-601-x/00105/4173282-eng.htm --> 18.3 TJ/(thousand of tons) --> 5e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 5e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#       Unnamed: 0 Country or Area                  Commodity - Transaction  \
# 0              0       Australia         Sub-bituminous coal - Production
# 1              1       Australia         Sub-bituminous coal - Production
# 2              2       Australia         Sub-bituminous coal - Production
# 3              3       Australia         Sub-bituminous coal - Production
# 4              4       Australia         Sub-bituminous coal - Production
# ...          ...             ...                                      ...
# 6834        6834   United States  Sub-bituminous coal - Final consumption
# 6835        6835   United States  Sub-bituminous coal - Final consumption
# 6836        6836   United States  Sub-bituminous coal - Final consumption
# 6837        6837   United States  Sub-bituminous coal - Final consumption
# 6838        6838   United States  Sub-bituminous coal - Final consumption
#
#                 Commodity        Transaction  Year                    Unit  \
# ...

# %%
FILE_NAME = 'Total Electricity 1'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 10e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area  \
# 0               0     Afghanistan
# 1               1     Afghanistan
# 2               2     Afghanistan
# 3               3     Afghanistan
# 4               4     Afghanistan
# ...           ...             ...
# 99777       99777          Malawi
# 99778       99778          Malawi
# 99779       99779          Malawi
# 99780       99780          Malawi
# 99781       99781          Malawi
#
#                             Commodity - Transaction    Commodity  \
# 0                    Electricity - Gross production  Electricity
# 1                    Electricity - Gross production  Electricity
# 2                    Electricity - Gross production  Electricity
# 3                    Electricity - Gross production  Electricity
# 4                    Electricity - Gross production  Electricity
# ...                                             ...          ...
# 99777  Electricity - total production, autoproducer  Electricity
# ...

# %%
FILE_NAME = 'Total Electricity 2'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 10e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0 Country or Area  \
# 0               0        Malaysia
# 1               1        Malaysia
# 2               2        Malaysia
# 3               3        Malaysia
# 4               4        Malaysia
# ...           ...             ...
# 80891       80891        Zimbabwe
# 80892       80892        Zimbabwe
# 80893       80893        Zimbabwe
# 80894       80894        Zimbabwe
# 80895       80895        Zimbabwe
#
#                             Commodity - Transaction    Commodity  \
# 0                    Electricity - Gross production  Electricity
# 1                    Electricity - Gross production  Electricity
# 2                    Electricity - Gross production  Electricity
# 3                    Electricity - Gross production  Electricity
# 4                    Electricity - Gross production  Electricity
# ...                                             ...          ...
# 80891  Electricity - total production, autoproducer  Electricity
# ...

# %%
FILE_NAME = 'Whitespirit and special boiling point industrial spirits'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
#https://mdgs.un.org/unsd/energy/balance/2013/05.pdf --> 40.2 TJ/(thousand of tons) --> 11.1e6 kWh/(thousand of tons)
df['Conversion_in_kWh'] = 11.1e6*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0           Country or Area  \
# 0               0               Afghanistan
# 1               1               Afghanistan
# 2               2               Afghanistan
# 3               3               Afghanistan
# 4               4               Afghanistan
# ...           ...                       ...
# 12354       12354  Yugoslavia, SFR (former)
# 12355       12355  Yugoslavia, SFR (former)
# 12356       12356  Yugoslavia, SFR (former)
# 12357       12357  Yugoslavia, SFR (former)
# 12358       12358  Yugoslavia, SFR (former)
#
#                                  Commodity - Transaction  \
# 0      White spirit and special boiling point industr...
# 1      White spirit and special boiling point industr...
# 2      White spirit and special boiling point industr...
# 3      White spirit and special boiling point industr...
# 4      White spirit and special boiling point industr...
# ...                                                  ...
# ...

# %%
FILE_NAME = 'Naptha'
df = pd.read_csv(DATA_PATH + FILE_NAME + '.csv')
df['Conversion_in_kWh'] = 277778*df['Quantity']
df.to_csv('Converted/' + FILE_NAME + ' converted.csv')
df
# Out:
#        Unnamed: 0           Country or Area        Commodity - Transaction  \
# 0               0                   Albania           Naphtha - Production
# 1               1                   Albania           Naphtha - Production
# 2               2                   Albania           Naphtha - Production
# 3               3                   Albania           Naphtha - Production
# 4               4                   Albania           Naphtha - Production
# ...           ...                       ...                            ...
# 19963       19963  Yugoslavia, SFR (former)      Naphtha - Non-energy uses
# 19964       19964  Yugoslavia, SFR (former)  Naphtha - Total energy supply
# 19965       19965  Yugoslavia, SFR (former)  Naphtha - Total energy supply
# 19966       19966  Yugoslavia, SFR (former)    Naphtha - Final consumption
# 19967       19967  Yugoslavia, SFR (former)    Naphtha - Final consumption
#
# ...
